# %% [markdown]
# # Data Preprocessing
#
# ---
#
# ## Purpose
#
# This notebook prepares the raw data for analysis and modeling by cleaning and transforming variables.
#
# - Load and inspect the raw dataset
# - Handle missing values through imputation
# - Generate summary statistics to understand variable distributions
# - Create bivariate reports to check relationships with the target
# - Transform key features for better model performance

# %%
# !pip install -r ../requirements.txt -q

# %%
# import packages
import os
import csv
import numpy as np
import pandas as pd
import warnings

# visualization package
import seaborn as sns
import matplotlib.pyplot as plt

# ignore warning
warnings.filterwarnings("ignore")

from utils import *

# %% [markdown]
# ### Load Data

# %%
with open("../data/census-bureau.columns") as f:
    columns = [line.strip() for line in f]

# %%
len(columns)
# Out:
# 42

# %%
df = pd.read_csv(
    "../data/census-bureau.data",
    header=None,
    names=columns,
    sep=",",
    engine="python",
)

# %%
# replace " ", ? and NA values with NaN
df = df.replace("", np.nan)
df = df.replace("NA", np.nan)
df = df.replace("none", np.nan)
df = df.replace("?", np.nan)

# %%
# number of records and fields in the data
print(df.shape)
print(f"Number of records: {df.shape[0]}")
print(f"Number of fields: {df.shape[1]}")
# Out:
# (199523, 42)
# Number of records: 199523
# Number of fields: 42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199523 entries, 0 to 199522
# Data columns (total 42 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   age                                         199523 non-null  int64
#  1   class of worker                             199523 non-null  object
#  2   detailed industry recode                    199523 non-null  int64
#  3   detailed occupation recode                  199523 non-null  int64
#  4   education                                   199523 non-null  object
#  5   wage per hour                               199523 non-null  int64
#  6   enroll in edu inst last wk                  199523 non-null  object
#  7   marital stat                                199523 non-null  object
#  8   major industry code                         199523 non-null  object
#  9   major occupation code                       199523 non-null  object
#  10  race                                        199523 non-null  object
#  11  hispanic origin                             198649 non-null  object
#  12  sex                                         199523 non-null  object
#  13  member of a labor union                     199523 non-null  object
#  14  reason for unemployment                     199523 non-null  object
#  15  full or part time employment stat           199523 non-null  object
#  16  capital gains                               199523 non-null  int64
#  17  capital losses                              199523 non-null  int64
#  18  dividends from stocks                       199523 non-null  int64
#  19  tax filer stat                              199523 non-null  object
#  20  region of previous residence                199523 non-null  object
#  21  state of previous residence                 198815 non-null  object
#  22  detailed household and family stat          199523 non-null  object
#  23  detailed household summary in household     199523 non-null  object
#  24  weight                                      199523 non-null  float64
#  25  migration code-change in msa                99827 non-null   object
#  26  migration code-change in reg                99827 non-null   object
#  27  migration code-move within reg              99827 non-null   object
#  28  live in this house 1 year ago               199523 non-null  object
#  29  migration prev res in sunbelt               99827 non-null   object
#  30  num persons worked for employer             199523 non-null  int64
#  31  family members under 18                     199523 non-null  object
#  32  country of birth father                     192810 non-null  object
#  33  country of birth mother                     193404 non-null  object
#  34  country of birth self                       196130 non-null  object
#  35  citizenship                                 199523 non-null  object
#  36  own business or self employed               199523 non-null  int64
#  37  fill inc questionnaire for veteran's admin  199523 non-null  object
#  38  veterans benefits                           199523 non-null  int64
#  39  weeks worked in year                        199523 non-null  int64
#  40  year                                        199523 non-null  int64
#  41  label                                       199523 non-null  object
# dtypes: float64(1), int64(12), object(29)
# memory usage: 63.9+ MB

# %%
df.label.value_counts()
# Out:
# label
# - 50000.    187141
# 50000+.      12382
# Name: count, dtype: int64

# %%
df["label"] = df["label"].str.strip()
df["label"] = df["label"].map({"50000+.": 1, "- 50000.": 0})

# %%
df.label.value_counts()
# Out:
# label
# 0    187141
# 1     12382
# Name: count, dtype: int64

# %%
# Unweighted event rate
unweighted_rate = df["label"].mean()
print(f"Unweighted event rate: {unweighted_rate:.2%}")

# Weighted event rate
weighted_rate = np.average(df["label"], weights=df["weight"])
print(f"Weighted event rate: {weighted_rate:.2%}")
# Out:
# Unweighted event rate: 6.21%
# Weighted event rate: 6.41%

# %%
# Clean the string columns
df = clean_string_values(df)

# %%
df.columns = df.columns.str.replace(" ", "_").str.lower()

# %%
df.shape
# Out:
# (199523, 42)

# %%
df.head(2)
# Out:
#    age                 class_of_worker  detailed_industry_recode  \
# 0   73                 not in universe                         0
# 1   58  self-employed-not incorporated                         4
#
#    detailed_occupation_recode                   education  wage_per_hour  \
# 0                           0        high school graduate              0
# 1                          34  some college but no degree              0
#
#   enroll_in_edu_inst_last_wk marital_stat          major_industry_code  \
# 0            not in universe      widowed  not in universe or children
# 1            not in universe     divorced                 construction
#
#                  major_occupation_code  ... country_of_birth_father  \
# 0                      not in universe  ...           united-states
# 1  precision production craft & repair  ...           united-states
#
#   country_of_birth_mother country_of_birth_self  \
# 0           united-states         united-states
# 1           united-states         united-states
#
#                          citizenship own_business_or_self_employed  \
# 0  native- born in the united states                             0
# 1  native- born in the united states                             0
#
#   fill_inc_questionnaire_for_veteran's_admin  veterans_benefits  \
# 0                            not in universe                  2
# 1                            not in universe                  2
#
#    weeks_worked_in_year  year label
# 0                     0    95     0
# 1                    52    94     0
#
# [2 rows x 42 columns]

# %%
df.year.value_counts()
# Out:
# year
# 94    99827
# 95    99696
# Name: count, dtype: int64

# %% [markdown]
# ### Summarise Data

# %%
summary_df = summary_statistics(df)
summary_df["percentage_missing_cnt"] = summary_df["Missing_Count"] * 100 / df.shape[0]
summary_df
# Out:
#                                  Variable_Name Variable_Type  Missing_Count  \
# 0                                          age    Continuous              0
# 1                              class_of_worker   Categorical              0
# 2                     detailed_industry_recode    Continuous              0
# 3                   detailed_occupation_recode    Continuous              0
# 4                                    education   Categorical              0
# 5                                wage_per_hour    Continuous              0
# 6                   enroll_in_edu_inst_last_wk   Categorical              0
# 7                                 marital_stat   Categorical              0
# 8                          major_industry_code   Categorical              0
# 9                        major_occupation_code   Categorical              0
# 10                                        race   Categorical              0
# 11                             hispanic_origin   Categorical            874
# 12                                         sex   Categorical              0
# 13                     member_of_a_labor_union   Categorical              0
# 14                     reason_for_unemployment   Categorical              0
# 15           full_or_part_time_employment_stat   Categorical              0
# 16                               capital_gains    Continuous              0
# 17                              capital_losses    Continuous              0
# 18                       dividends_from_stocks    Continuous              0
# 19                              tax_filer_stat   Categorical              0
# 20                region_of_previous_residence   Categorical              0
# 21                 state_of_previous_residence   Categorical            708
# 22          detailed_household_and_family_stat   Categorical              0
# 23     detailed_household_summary_in_household   Categorical              0
# 24                                      weight    Continuous              0
# 25                migration_code-change_in_msa   Categorical          99696
# 26                migration_code-change_in_reg   Categorical          99696
# 27              migration_code-move_within_reg   Categorical          99696
# 28               live_in_this_house_1_year_ago   Categorical              0
# 29               migration_prev_res_in_sunbelt   Categorical          99696
# 30             num_persons_worked_for_employer    Continuous              0
# 31                     family_members_under_18   Categorical              0
# 32                     country_of_birth_father   Categorical           6713
# 33                     country_of_birth_mother   Categorical           6119
# 34                       country_of_birth_self   Categorical           3393
# 35                                 citizenship   Categorical              0
# 36               own_business_or_self_employed    Continuous              0
# 37  fill_inc_questionnaire_for_veteran's_admin   Categorical              0
# 38                           veterans_benefits    Continuous              0
# 39                        weeks_worked_in_year    Continuous              0
# 40                                        year    Continuous              0
# 41                                       label    Continuous              0
#
#                   Most_Frequent_Value         Mean Standard_Deviation    Min  \
# 0                                  34    34.494199          22.310895      0
# 1                     not in universe           NA                 NA     NA
# 2                                   0     15.35232          18.067129      0
# 3                                   0    11.306556          14.454204      0
# 4                high school graduate           NA                 NA     NA
# 5                                   0    55.426908         274.896454      0
# 6                     not in universe           NA                 NA     NA
# 7                       never married           NA                 NA     NA
# 8         not in universe or children           NA                 NA     NA
# 9                     not in universe           NA                 NA     NA
# 10                              white           NA                 NA     NA
# 11                          all other           NA                 NA     NA
# 12                             female           NA                 NA     NA
# 13                    not in universe           NA                 NA     NA
# 14                    not in universe           NA                 NA     NA
# 15           children or armed forces           NA                 NA     NA
# 16                                  0    434.71899         4697.53128      0
# 17                                  0    37.313788         271.896428      0
# 18                                  0   197.529533        1984.163658      0
# 19                           nonfiler           NA                 NA     NA
# 20                    not in universe           NA                 NA     NA
# 21                    not in universe           NA                 NA     NA
# 22                        householder           NA                 NA     NA
# 23                        householder           NA                 NA     NA
# 24                             753.23  1740.380269         993.768156  37.87
# 25                           nonmover           NA                 NA     NA
# 26                           nonmover           NA                 NA     NA
# 27                           nonmover           NA                 NA     NA
# 28   not in universe under 1 year old           NA                 NA     NA
# 29                    not in universe           NA                 NA     NA
# 30                                  0      1.95618           2.365126      0
# 31                    not in universe           NA                 NA     NA
# 32                      united-states           NA                 NA     NA
# 33                      united-states           NA                 NA     NA
# 34                      united-states           NA                 NA     NA
# 35  native- born in the united states           NA                 NA     NA
# 36                                  0     0.175438           0.553694      0
# 37                    not in universe           NA                 NA     NA
# 38                                  2     1.514833           0.851473      0
# 39                                  0    23.174897          24.411488      0
# 40                                 94    94.499672           0.500001     94
# 41                                  0     0.062058           0.241261      0
#
#         Max  Unique_Values IQR_Outliers 5th percentile 10th percentile  \
# 0        90             91          0.0            3.0             6.0
# 1        NA              9           NA             NA              NA
# 2        51             52          0.0            0.0             0.0
# 3        46             47          0.0            0.0             0.0
# 4        NA             17           NA             NA              NA
# 5      9999           1240     5.665512            0.0             0.0
# 6        NA              3           NA             NA              NA
# 7        NA              7           NA             NA              NA
# 8        NA             24           NA             NA              NA
# 9        NA             15           NA             NA              NA
# 10       NA              5           NA             NA              NA
# 11       NA              9           NA             NA              NA
# 12       NA              2           NA             NA              NA
# 13       NA              3           NA             NA              NA
# 14       NA              6           NA             NA              NA
# 15       NA              8           NA             NA              NA
# 16    99999            132      3.69832            0.0             0.0
# 17     4608            113     1.957669            0.0             0.0
# 18    99999           1478    10.595771            0.0             0.0
# 19       NA              6           NA             NA              NA
# 20       NA              6           NA             NA              NA
# 21       NA             50           NA             NA              NA
# 22       NA             38           NA             NA              NA
# 23       NA              8           NA             NA              NA
# 24  18656.3          99800     3.126457        395.342         596.242
# 25       NA              9           NA             NA              NA
# 26       NA              8           NA             NA              NA
# 27       NA              9           NA             NA              NA
# 28       NA              3           NA             NA              NA
# 29       NA              3           NA             NA              NA
# 30        6              7          0.0            0.0             0.0
# 31       NA              5           NA             NA              NA
# 32       NA             42           NA             NA              NA
# 33       NA             42           NA             NA              NA
# 34       NA             42           NA             NA              NA
# 35       NA              5           NA             NA              NA
# 36        2              3     9.448034            0.0             0.0
# 37       NA              3           NA             NA              NA
# 38        2              3    24.755542            0.0             0.0
# 39       52             53          0.0            0.0             0.0
# 40       95              2          0.0           94.0            94.0
# 41        1              2     6.205801            0.0             0.0
#
#    25th percentile 50th percentile (Median) 75th percentile 90th percentile  \
# 0             15.0                     33.0            50.0            67.0
# 1               NA                       NA              NA              NA
# 2              0.0                      0.0            33.0            43.0
# 3              0.0                      0.0            26.0            35.0
# 4               NA                       NA              NA              NA
# 5              0.0                      0.0             0.0             0.0
# 6               NA                       NA              NA              NA
# 7               NA                       NA              NA              NA
# 8               NA                       NA              NA              NA
# 9               NA                       NA              NA              NA
# 10              NA                       NA              NA              NA
# 11              NA                       NA              NA              NA
# 12              NA                       NA              NA              NA
# 13              NA                       NA              NA              NA
# 14              NA                       NA              NA              NA
# 15              NA                       NA              NA              NA
# 16             0.0                      0.0             0.0             0.0
# 17             0.0                      0.0             0.0             0.0
# 18             0.0                      0.0             0.0             7.0
# 19              NA                       NA              NA              NA
# 20              NA                       NA              NA              NA
# 21              NA                       NA              NA              NA
# 22              NA                       NA              NA              NA
# 23              NA                       NA              NA              NA
# 24        1061.615                  1618.31         2188.61        3059.822
# 25              NA                       NA              NA              NA
# 26              NA                       NA              NA              NA
# 27              NA                       NA              NA              NA
# 28              NA                       NA              NA              NA
# 29              NA                       NA              NA              NA
# 30             0.0                      1.0             4.0             6.0
# 31              NA                       NA              NA              NA
# 32              NA                       NA              NA              NA
# 33              NA                       NA              NA              NA
# 34              NA                       NA              NA              NA
# 35              NA                       NA              NA              NA
# 36             0.0                      0.0             0.0             0.0
# 37              NA                       NA              NA              NA
# 38             2.0                      2.0             2.0             2.0
# 39             0.0                      8.0            52.0            52.0
# 40            94.0                     94.0            95.0            95.0
# 41             0.0                      0.0             0.0             0.0
#
#    95th percentile Percentage_of_Zeros Percentage_of_Negatives  \
# 0             75.0            1.422894                     0.0
# 1               NA                  NA                      NA
# 2             44.0           50.462353                     0.0
# 3             38.0           50.462353                     0.0
# 4               NA                  NA                      NA
# 5            495.0           94.334488                     0.0
# 6               NA                  NA                      NA
# 7               NA                  NA                      NA
# 8               NA                  NA                      NA
# 9               NA                  NA                      NA
# 10              NA                  NA                      NA
# 11              NA                  NA                      NA
# 12              NA                  NA                      NA
# 13              NA                  NA                      NA
# 14              NA                  NA                      NA
# 15              NA                  NA                      NA
# 16             0.0            96.30168                     0.0
# 17             0.0           98.042331                     0.0
# 18           400.0           89.404229                     0.0
# 19              NA                  NA                      NA
# 20              NA                  NA                      NA
# 21              NA                  NA                      NA
# 22              NA                  NA                      NA
# 23              NA                  NA                      NA
# 24        3585.909                 0.0                     0.0
# 25              NA                  NA                      NA
# 26              NA                  NA                      NA
# 27              NA                  NA                      NA
# 28              NA                  NA                      NA
# 29              NA                  NA                      NA
# 30             6.0           48.106233                     0.0
# 31              NA                  NA                      NA
# 32              NA                  NA                      NA
# 33              NA                  NA                      NA
# 34              NA                  NA                      NA
# 35              NA                  NA                      NA
# 36             2.0           90.551966                     0.0
# 37              NA                  NA                      NA
# 38             2.0            23.76117                     0.0
# 39            52.0           48.106233                     0.0
# 40            95.0                 0.0                     0.0
# 41             1.0           93.794199                     0.0
#
#     percentage_missing_cnt
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# 3                 0.000000
# 4                 0.000000
# 5                 0.000000
# 6                 0.000000
# 7                 0.000000
# 8                 0.000000
# 9                 0.000000
# 10                0.000000
# 11                0.438045
# 12                0.000000
# 13                0.000000
# 14                0.000000
# 15                0.000000
# 16                0.000000
# 17                0.000000
# 18                0.000000
# 19                0.000000
# 20                0.000000
# 21                0.354846
# 22                0.000000
# 23                0.000000
# 24                0.000000
# 25               49.967172
# 26               49.967172
# 27               49.967172
# 28                0.000000
# 29               49.967172
# 30                0.000000
# 31                0.000000
# 32                3.364524
# 33                3.066814
# 34                1.700556
# 35                0.000000
# 36                0.000000
# 37                0.000000
# 38                0.000000
# 39                0.000000
# 40                0.000000
# 41                0.000000

# %%
summary_df.to_excel("../artifacts/data_quality/summary_report.xlsx", index=False)

# %% [markdown]
# ### Mappings and transformations

# %%
df["education"].value_counts()
# Out:
# education
# high school graduate                      48407
# children                                  47422
# some college but no degree                27820
# bachelors degree(ba ab bs)                19865
# 7th and 8th grade                          8007
# 10th grade                                 7557
# 11th grade                                 6876
# masters degree(ma ms meng med msw mba)     6541
# 9th grade                                  6230
# associates degree-occup /vocational        5358
# associates degree-academic program         4363
# 5th or 6th grade                           3277
# 12th grade no diploma                      2126
# 1st 2nd 3rd or 4th grade                   1799
# prof school degree (md dds dvm llb jd)     1793
# doctorate degree(phd edd)                  1263
# less than 1st grade                         819
# Name: count, dtype: int64

# %% [markdown]
# #### 1. Education to Ordinal Variable

# %%
education_mapping = {
    "children": 1,
    "less than 1st grade": 2,
    "1st 2nd 3rd or 4th grade": 3,
    "5th or 6th grade": 4,
    "7th and 8th grade": 5,
    "9th grade": 6,
    "10th grade": 7,
    "11th grade": 8,
    "12th grade no diploma": 9,
    "high school graduate": 10,
    "some college but no degree": 11,
    "associates degree-occup /vocational": 12,
    "associates degree-academic program": 13,
    "bachelors degree(ba ab bs)": 14,
    "masters degree(ma ms meng med msw mba)": 15,
    "prof school degree (md dds dvm llb jd)": 16,
    "doctorate degree(phd edd)": 17,
}

df["education_numeric"] = df["education"].map(education_mapping)

if df["education_numeric"].isna().any():
    df["education_numeric"] = df["education_numeric"].fillna(
        df["education_numeric"].median()
    )

display(
    df.groupby(["education", "education_numeric"])
    .size()
    .reset_index(name="count")
    .sort_values(["education_numeric"])
)

df.drop(columns="education", inplace=True)
# Out:
#                                  education  education_numeric  count
# 10                                children                  1  47422
# 13                     less than 1st grade                  2    819
# 3                 1st 2nd 3rd or 4th grade                  3   1799
# 4                         5th or 6th grade                  4   3277
# 5                        7th and 8th grade                  5   8007
# 6                                9th grade                  6   6230
# 0                               10th grade                  7   7557
# 1                               11th grade                  8   6876
# 2                    12th grade no diploma                  9   2126
# 12                    high school graduate                 10  48407
# 16              some college but no degree                 11  27820
# 8      associates degree-occup /vocational                 12   5358
# 7       associates degree-academic program                 13   4363
# 9               bachelors degree(ba ab bs)                 14  19865
# 14  masters degree(ma ms meng med msw mba)                 15   6541
# 15  prof school degree (md dds dvm llb jd)                 16   1793
# 11               doctorate degree(phd edd)                 17   1263

# %% [markdown]
# #### 2. Binary flags for `country_of_birth_father`, `country_of_birth_mother`, `country_of_birth_self`

# %%
cols_to_transform = [
    "country_of_birth_father",
    "country_of_birth_mother",
    "country_of_birth_self",
]

for col in cols_to_transform:
    new_col_name = f"{col}_is_usa"
    df[new_col_name] = df[col].apply(
        lambda x: 1 if str(x).strip().lower() == "united-states" else 0
    )

    display(df.groupby(f"{col}_is_usa").size().reset_index(name="count"))

    df.drop(columns=col, inplace=True)
# Out:
#    country_of_birth_father_is_usa   count
# 0                               0   40360
# 1                               1  159163
#    country_of_birth_mother_is_usa   count
# 0                               0   39044
# 1                               1  160479
#    country_of_birth_self_is_usa   count
# 0                             0   22534
# 1                             1  176989

# %% [markdown]
# #### 3. Combine categories for `state_of_previous_residence`

# %%
df["state_of_previous_residence"] = df["state_of_previous_residence"].apply(
    get_state_mapping
)

display(df.groupby("state_of_previous_residence").size().reset_index(name="count"))
# Out:
#   state_of_previous_residence   count
# 0                      abroad     671
# 1             not in universe  184458
# 2                    us_state   14394

# %% [markdown]
# #### 4. Binary flag for `sex`

# %%
df["sex"] = df["sex"].str.strip()
df["sex_is_male"] = df["sex"].map({"male": 1, "female": 0})
df.drop(columns="sex", inplace=True)
df.sex_is_male.value_counts()
# Out:
# sex_is_male
# 0    103984
# 1     95539
# Name: count, dtype: int64

# %% [markdown]
# #### 5.Log Transformation for  `capital_gains`, `capital_losses`, `dividends_from_stocks`

# %%
cols_to_transform = ["capital_gains", "capital_losses", "dividends_from_stocks"]

for col in cols_to_transform:
    df[f"has_{col}"] = (df[col] > 0).astype(int)
    display(df.groupby(f"has_{col}").size().reset_index(name="count"))

for col in cols_to_transform:
    df[f"{col}_log"] = np.log1p(df[col])
    df.drop(columns=col, inplace=True)
# Out:
#    has_capital_gains   count
# 0                  0  192144
# 1                  1    7379
#    has_capital_losses   count
# 0                   0  195617
# 1                   1    3906
#    has_dividends_from_stocks   count
# 0                          0  178382
# 1                          1   21141

# %% [markdown]
# ### Get Bi-variate analsyis for categorical variables

# %%
report_df = bivariate_report(df, "label")

# %%
report_df.head(9)
# Out:
#           Variable                        Category  Count_1  Count_0  \
# 0  class_of_worker              federal government    597.0   2328.0
# 1  class_of_worker                local government    847.0   6937.0
# 2  class_of_worker                    never worked      2.0    437.0
# 3  class_of_worker                 not in universe    904.0  99341.0
# 4  class_of_worker                         private   7322.0  64706.0
# 5  class_of_worker      self-employed-incorporated   1134.0   2131.0
# 6  class_of_worker  self-employed-not incorporated   1090.0   7355.0
# 7  class_of_worker                state government    485.0   3742.0
# 8  class_of_worker                     without pay      1.0    164.0
#
#       Total  Event_Rate_%  Weighted_Event_Rate_%  Population_%  \
# 0    2925.0         20.41                  21.08          1.47
# 1    7784.0         10.88                  11.22          3.90
# 2     439.0          0.46                   0.29          0.22
# 3  100245.0          0.90                   0.94         50.24
# 4   72028.0         10.17                  10.22         36.10
# 5    3265.0         34.73                  36.26          1.64
# 6    8445.0         12.91                  13.29          4.23
# 7    4227.0         11.47                  11.72          2.12
# 8     165.0          0.61                   0.18          0.08
#
#    Weighted_Population_%
# 0                   1.46
# 1                   3.96
# 2                   0.23
# 3                  49.21
# 4                  37.20
# 5                   1.63
# 6                   4.18
# 7                   2.06
# 8                   0.08

# %%
report_df.to_excel("../artifacts/data_quality/bivariate_report.xlsx", index=False)

# %%
# saving a parquet file
df.to_parquet("../data/processed_data.parquet", engine="pyarrow", index=False)
